# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def min_filter(image, kernel_size=3):
    # Apply the min filter using a sliding window approach
    return cv2.erode(image, np.ones((kernel_size, kernel_size), np.uint8))

# Read an image
image = cv2.imread('import cv2')
import numpy as np
import matplotlib.pyplot as plt

def min_filter(image, kernel_size=3):
    # Apply the min filter using a sliding window approach
    return cv2.erode(image, np.ones((kernel_size, kernel_size), np.uint8))

# Read an image
image = cv2.imread('/content/URMILA.webp', cv2.IMREAD_GRAYSCALE)

# Apply the min filter with a 3x3 kernel
filtered_image = min_filter(image, kernel_size=3)

# Display original and filtered images
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

# Filtered Image
plt.subplot(1, 2, 2)
plt.imshow(filtered_image, cmap='gray')
plt.title('Min Filtered Image')
plt.axis('off')

plt.show()
(' cv2.IMREAD_GRAYSCALE')

# Apply the min filter with a 3x3 kernel
filtered_image = min_filter(image, kernel_size=3)

# Display original and filtered images
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

# Filtered Image
plt.subplot(1, 2, 2)
plt.imshow(filtered_image, cmap='gray')
plt.title('Min Filtered Image')
plt.axis('off')

plt.show()
